# %%
include("./fig51.jl")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
include("./fig52.jl")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)

# %%
include("./fig6.jl")
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)
